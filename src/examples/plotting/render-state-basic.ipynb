# %% [markdown]
# # Visualizing and incrementally adding CrossCat models in iventure
#
# __To produce visual rendering of models__
# ```
# usage: %bql .render_crosscat [options] <metamodel_name> <model_number>
#
# options:
#     --width=<w>                   width of the figure
#     --height=<c>                  height of the figure
#     --rowlabels=<colname>         name of the column in the base table to use as row labels.
#     --progress=[True|False]       show a progress bar?
#     --yticklabeslize=<fontsize>   size of the row labels
#     --xticklabeslize=<fontsize>   size of the col labels
# ```
#
# _Note_: To view a figure in full size, right-click and select 'Open in image in new tab'.
#
# __To initialize more models to existing metamdoel__
# ```
# usage: %mml INITIALIZE <n> MODELS IF NOT EXIST FOR <metamodel_name>
#
# Ensures <metamodel_name> has at least <n> models in total.
#
# If models [1..<k>] are already initialized for <metamodel_name>, then a new
# set of models [<k+1>..<n>] will be initialized and appended to the metamodel.
# ```

# %%
# %load_ext iventure.magics
# %matplotlib inline
# Out:
# session_id: fsaad_2017-06-19T18:35:03.613032_7

# %% [markdown]
# ### Load data table and create a population.

# %%
# !rm -f resources/satellites.render.subsample.bdb
# %bayesdb resources/satellites.render.subsample.bdb
# Out:
# u'Loaded: resources/satellites.render.subsample.bdb'

# %%
# %bql CREATE TABLE satellites_t FROM 'resources/satellites.csv'
# %bql .nullify satellites_t NaN
# Out:
# Nullified 3032 cells

# %%
# %%mml
# CREATE POPULATION satellites FOR satellites_t WITH SCHEMA(
#     GUESS STATTYPES FOR (*);
# )
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create a metamodel with 1 model and 50 subsampled satellites.

# %%
# %mml CREATE METAMODEL satellites_m FOR satellites WITH BASELINE crosscat (SUBSAMPLE 50);
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %mml INITIALIZE 1 MODELS FOR satellites_m;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Render the CrossCat state as sampled from the prior.

# %%
# %mml .render_crosscat --progress=True --rowlabels=Name satellites_m 0
# Out:
# Creating figure...
# [==============================] 100.00%
# Rendering figure...

# %% [markdown]
# ### Show a dependence heatmap from the single model.

# %%
# %bql .heatmap ESTIMATE DEPENDENCE PROBABILITY FROM PAIRWISE VARIABLES OF satellites

# %% [markdown]
# ### Run 250 iterations of analysis (all kernels).

# %%
# %mml ANALYZE satellites_m FOR 250 ITERATION WAIT (OPTIMIZED);
# Out:
# Completed: 250 iterations in 6.323727 seconds.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Render the CrossCat model after analysis and show new dependencies.

# %%
# %mml .render_crosscat --progress=True --yticklabelsize=small --rowlabels=Name satellites_m 0
# Out:
# Creating figure...
# [==============================] 100.00%
# Rendering figure...

# %%
# %bql .heatmap ESTIMATE DEPENDENCE PROBABILITY FROM PAIRWISE VARIABLES OF satellites;

# %% [markdown]
# ### Dependencies and clusters in the view of a fixed variable are specified using --variable=&lt;name&gt;

# %%
# %mml .render_crosscat --yticklabelsize=small --variable=class_of_orbit --height=10 --rowlabels=Name satellites_m 0

# %% [markdown]
# ### Initialize 15 more models for the metamodel, and render some models sampled from the prior.

# %%
# %mml INITIALIZE 16 MODELS IF NOT EXISTS FOR satellites_m;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %mml .render_crosscat --rowlabels=Name satellites_m 2
# %mml .render_crosscat --rowlabels=Name satellites_m 3
# %mml .render_crosscat --rowlabels=Name satellites_m 4

# %% [markdown]
# ### Run 500 iterations of analysis.

# %%
# %multiprocess on
# %mml ANALYZE satellites_m FOR 250 ITERATION WAIT (OPTIMIZED);
# Out:
# Multiprocessing turned on from off.
# Completed: 250 iterations in 6.576992 seconds.
# Completed: 250 iterations in 6.618662 seconds.
# Completed: 250 iterations in 6.645854 seconds.
# Completed: 250 iterations in 6.691926 seconds.
# Completed: 250 iterations in 6.707597 seconds.
# Completed: 250 iterations in 6.734258 seconds.
# Completed: 250 iterations in 6.776402 seconds.
# Completed: 250 iterations in 6.817437 seconds.
# Completed: 250 iterations in 6.852199 seconds.
# Completed: 250 iterations in 6.910898 seconds.
# Completed: 250 iterations in 6.897959 seconds.
# Completed: 250 iterations in 6.951248 seconds.
# Completed: 250 iterations in 7.139457 seconds.
# Completed: 250 iterations in 7.206685 seconds.
# Completed: 250 iterations in 7.429109 seconds.
# Completed: 250 iterations in 7.689259 seconds.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %mml .render_crosscat --yticklabelsize=x-small --rowlabels=Name satellites_m 2
# %mml .render_crosscat --yticklabelsize=x-small --rowlabels=Name satellites_m 3
# %mml .render_crosscat --yticklabelsize=x-small --rowlabels=Name satellites_m 4

# %% [markdown]
# ### Show dependence heatmap aggregating over the models.

# %%
# %bql .heatmap ESTIMATE DEPENDENCE PROBABILITY FROM PAIRWISE VARIABLES OF satellites;
